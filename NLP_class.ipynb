# %% [markdown]
# # #Python으로 영어 코퍼스 처리

# %% [markdown]
# # < Sentiment analysis process>
#
# step1. 데이터 수집 및 탐색
#
# step2. 전처리
#     - Tokenize text (stemming)
#     - Tag token (POS, NER)
#     - Token selection ( stopword removal)
#     - calculate word/docnment similarities, cluster documments
#
# step3. 속성 추출
#
# step4. 기계학습 알고리즘 및 평가

# %% [markdown]
# # 용어
#
# Document : 문서
#
# Corpus - 말뭉치
#
# Token - 토큰 (Meaning elements in a document. words, phrases, sentences..)
#
# POS - 품사  (Part-of-speech ; Nouns ...)

# %% [markdown]
# # Text Mining을 위한 Python packages 설치
#
#
# step1: Install Anaconda3
#
# step2: NLTK 설치

# %% [markdown]
# pip install nltk
#
# nltk.download()

# %% [markdown]
# # 1. Document exploration
#
# NLTK에서 제공하는 문서들 또는 다른 텍스트를 로딩 사용

# %%
import nltk

# %%
from nltk.corpus import gutenberg # Doc from project gutenberg.org
files=gutenberg.fileids() # get file ids
print(files)

doc=gutenberg.open('austen-emma.txt').read()

tok=sent_tokenize(doc)

for x in range(5):
    print(tok[x])
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']
# [Emma by Jane Austen 1816]
#
# VOLUME I
#
# CHAPTER I
#
#
# Emma Woodhouse, handsome, clever, and rich, with a comfortable home
# and happy disposition, seemed to unite some of the best blessings
# of existence; and had lived nearly twenty-one years in the world
# with very little to distress or vex her.
# She was the youngest of the two daughters of a most affectionate,
# indulgent father; and had, in consequence of her sister's marriage,
# been mistress of his house from a very early period.
# Her mother
# had died too long ago for her to have more than an indistinct
# remembrance of her caresses; and her place had been supplied
# by an excellent woman as governess, who had fallen little short
# of a mother in affection.
# Sixteen years had Miss Taylor been in Mr. Woodhouse's family,
# less as a governess than a friend, very fond of both daughters,
# but particularly of Emma.
# Between _them_ it was more the intimacy
# of sisters.

# %% [markdown]
# # 2. Preprocessing

# %% [markdown]
# # regular expression:
#
#     match 1 or more (+)
#
#     match 0 or 1 repetitions(?)
#
#     match 0 or MORE repetitions (*)
#
#     Any character except a new line (.)

# %% [markdown]
# # 2-1. Tokenizing words with NLTK

# %%
from nltk.tokenize import sent_tokenize, word_tokenize, regexp_tokenize
                   
example_text = """Hello Mr. Smith, how are you doing today? 
The weather is great, and Python is awesome.
The sky is pinkish-blue. You shouldn't eat cardboard."""

print(sent_tokenize(example_text))
print(word_tokenize(example_text))

pattern= r'''[A-Z][a-z]*'''
print(regexp_tokenize(example_text,pattern))
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great, and Python is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard."]
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'Python', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard', '.']
# ['Hello', 'Mr', 'Smith', 'The', 'Python', 'The', 'You']

# %% [markdown]
# # 2-2. Explore Text with NLTK

# %%
pattern= r'''[a-z]*.'''
tokens = regexp_tokenize(doc, pattern)
data=nltk.Text(tokens)
print(len(data.tokens)) #returns number of tokens
print(set(data.tokens)) #returns number of unique tokens
data.vocab()  #returns frequency distribution
# Out:
# 221827
# {'cautiousness ', 'fellow.', 'half ', 'addition_', 'complained,', "farmer'", 'placed\n', 'placed,', 'currants ', 'greatcoat\n', 'kissed ', 'marriages\n', 'mmediately ', 'one?', 'ourselves,', 'evident.', 'distress;', 'abruptness ', 'back!', 'tolerable ', 'significant ', 'delicacy!', 'agreeable,', 'circumstance-', 'arrival,', 'umph-', 'watched ', 'regretted ', 'contemptuous\n', 'circles,', 'woman,', 'rational,', 'subsequent\n', 'concerned-', 'leisure\n', 'precious.', 'noise.', 'mith!', 'creature,', 'ath_', 'encountered\n', 'body!', 'extricated ', 'acted ', 'some_', 'conscious\n', 'ature ', 'transported ', 'compassion,', 'perhaps,', 'thousand ', 'match.', 'whether\n', 'mallridge,', 'unsteady;', 'scruples,', 'redeem ', 'sensibility\n', 'has ', 'dreaming ', 'conduct;', 'stake,', 'pass.', 'amongst\n', 'suggestion ', 'waltz;', 'fallen\n', 'alone.', 'quitted\n', 'named_', 'sir.', 'niece ', 'easy.', 'sublime ', 'whoever-', 'room?', 'wholesomeness ', 'repeated-', 'oodhouses\n', 'fire ', 'gracious,', 'person;', 'intentions.', 'greensward ', 'twice ', 'promises ', 'circumstance,', 'moderate,', 'discouragement\n', 'fear;', 'creatures!', 'entirely.', 'quare\n', 'huse ', 'lose.', 'quick.', 'wish.', 'ilberts,', 'thick\n', 'no;', 'them\n', 'courage ', 'sharp ', 'with?', 'ours.', 'andsome!', 'broken ', 'witnessed\n', 'trunk ', 'sinned ', 'nightley.', 'imagined ', 'hourly ', 'suspicious,', 'ourselves-', 'form.', 'aspect;', 'pitiable ', 'in ', 'portionless ', 'elder ', 'fetch\n', 'tranquillised ', 'welfare,', 'undoubtedly ', 'oftener ', 'armth ', 'rational\n', 'out!', 'aronne ', 'possibilities.', 'and_', 'side-', 'complaints ', 'frame ', 'provoking ', 'successfully.', 'before!', 'merit ', 'candles ', 'lurking ', 'talent ', 'public.', 'people-', 'obligation!', 'whoever ', 'again?', 'concerns,', 'heartily ', 'suspected\n', 'warmer,', 'civilly\n', 'astonishing\n', 'for?', 'purse,', 'plans.', 'on-', 'connexions,', 'shameful.', 'circumstance\n', 'planned;', 'small\n', 'hurchill!', 'out\n', 'y_', 'thinks\n', 'face ', 'devoted\n', 'supper-', 'blushed ', 'deciding\n', 'olonel\n', 'did-', 'distaste ', 'exultation,', 'dear,', 'longer-', 'himself,', 'up.', 'invalid-', 'unpleasant,', 'pleasure!', 'sweetbread ', 'natural:', 'warmly;', 'nobody.', 'discuss ', 'astonishment,', 'breathing!', 'anticipated-', 'daughters ', 'whim ', 'rain.', 'preserving ', 'plans ', 'passing\n', 'forward\n', 'sound.', 'triumph ', 'desperately\n', 'touch ', 'honoured.', 'marriage-', 'week.', 'talk-', 'preference\n', 'scrape,', 'persuaded,', 'speculation ', 'finished ', 'trifle,', 'habit-', 'lost!', 'handed ', 'hoped\n', 'aunt,', 'prospect,', 'declare!', 'boiled\n', "mma'", 'would_', 'intermediate ', 'fathomed ', 'excepted.', 'blown ', 'wine?', 'attentively.', 'delays\n', 'amazed.', 'heir,', 'else-', 'cool-', 'mean ', 'image ', 'meetings.', 'best ', 'apple-', 'scarcely\n', 'having,', 'anxiously\n', 'hearted-', 'night!', 'though\n', 'moment!', 'behind-', 'umph!', 'should\n', 'texts ', 'foot ', 'taste;', 'observing-', 'dispiriting ', 'zeal\n', 'eymouth ', 'uncertain ', 'drink ', 'associate,', 'deserve\n', 'ladies\n', 'caps.', 'gentle.', 'apprehension ', 'suffered.', 'exploring!', 'pen ', 'enclosed.', 'gratitude\n', 'shall\n', 'topic,', 'means-', 'rendered ', 'pocket-', 'intermission ', 'gaiters,', 'distress,', 'figure,', 'pondering,', 'infant,', 'alliance,', 'powers?', 'wife,', 'ere,', 'manner;', 'bbey,', 'supposes ', 'syllables\n', 'compliment ', 'walnuts\n', 'ight ', 'destroy ', 'safest ', 'inferior,', 'understands\n', 'retain ', 'hilip_', 'oddard?', 'sufferings ', 'healed ', 'kindred ', 'unpretending;', 'feelingly.', 'disliked ', 'colour ', 'ideas ', 'watering-', 'larger ', 'mutton ', 'overcharged ', 'communicative\n', 'incessant\n', 'enry,', 'errands\n', 'begged\n', 'ixty-', 'estimation,', 'invalids ', 'rejoiced ', 'emember ', 'remove.', 'delighted,', 'sleek,', 'broke_', 'irksome.', 'feelings,', 'education-', 'ten.', 'accent,', 'ran.', 'sacrifice ', 'undoubtedly;', 'estate,', 'curio ...
# FreqDist({'cautiousness ': 1,
#           'fellow.': 1,
#           'half ': 90,
#           'clear;': 1,
#           'complained,': 1,
#           "farmer'": 1,
#           'placed\n': 1,
#           'placed,': 1,
#           'greatcoat\n': 1,
#           'marriages\n': 1,
#           'mmediately ': 1,
#           'one?': 1,
#           'occupied,': 2,
#           'evident.': 2,
#           'distress;': 1,
#           'back!': 1,
#           'account\n': 4,
#           'tolerable ': 7,
#           'significant ': 2,
#           'bride-': 2,
#           'hints,': 2,
#           'delicacy!': 1,
#           'agreeable,': 7,
#           'circumstance-': 1,
#           'arrival,': 3,
#           'umph-': 1,
#           'watched ': 7,
#           'woman,': 22,
#           'rational,': 4,
#           'concerned-': 1,
#           'leisure\n': 1,
#           'precious.': 1,
#           'noise.': 2,
#           'mith!': 9,
#           'creature,': 6,
#           'ath_': 1,
#           'encountered\n': 1,
#           'body!': 2,
#           'extricated ': 1,
#           'conscious\n': 2,
#           'letting ': 3,
#           'transported ': 1,
#           'hold ': 11,
#           'ver ': 4,
#           'erle ': 3,
#           'compassion,': 4,
#           'perhaps,': 32,
#           'currants ': 1,
#           'thousand ': 14,
#           'match.': 7,
#           'scruples,': 1,
#           'unsteady;': 1,
#           'redeem ': 1,
#           'sensibility\n': 1,
#           'has ': 226,
#           'conduct;': 1,
#           'stake,': 1,
#           'pass.': 4,
#           'kissed ': 2,
#           'amongst\n': 2,
#           'suggestion ': 1,
#           'named_': 1,
#           'fallen\n': 2,
#           'alone.': 7,
#           'acknowledgment ': 3,
#           'sir.': 12,
#           'easy.': 4,
#           'sublime ': 1,
#           'whoever-': 1,
#           'room?': 1,
#           'wholesomeness ': 1,
#           'repeated-': 1,
#           'oodhouses\n': 1,
#           'seek,': 2,
#           'resent;': 1,
#           'fire ': 6,
#           'gracious,': 1,
#           'person;': 3,
#           'intentions.': 2,
#           'greensward ': 1,
#           'occupied\n': 4,
#           'twice ': 4,
#           'spoken,': 1,
#           'promises ': 3,
#           'circumstance,': 5,
#           'discouragement\n': 1,
#           'tilton ': 1,
#           'fear;': 1,
#           'entirely.': 2,
#           'quare\n': 1,
#           'lose.': 1,
#           'quick.': 3,
#           'wish.': 12,
#           'with?': 1,
#           'thick\n': 1,
#           'no;': 10,
#           'courage ': 5,
#           'sharp ': 2,
#           'ours.': 1,
#           'andsome!': 1,
#           'witnessed\n': 1,
#           'trunk ': 1,
#           'nightley.': 44,
#           'imagined ': 13,
#           'expression;': 1,
#           'hourly ': 1,
#           'suspicious,': 1,
#           'form.': 2,
#           'pitiable ': 1,
#           'in ': 2019,
#           'portionless ': 1,
#           'propriety.': 1,
#           'elder ': 3,
#           'welfare,': 1,
#           'tranquillised ': 1,
#           'opposed\n': 2,
#           'undoubtedly ': 7,
#           'mother ': 34,
#           'armth ': 1,
#           'tolerable;': 1,
#           'rational\n': 1,
#           'out!': 2,
#           'possibilities.': 1,
#           'and_': 1,
#           'side-': 3,
#           'while,': 7,
#           'frame ': 1,
#           'provoking ': 2,
#           'successfully.': 1,
#           'merit ': 7,
#           'candles ': 3,
#           'lurking ': 1,
#           'talent ': 6,
#           'people-': 2,
#           'whoever ': 1,
#           'concerns,': 1,
#           'accepted,': 2,
#           'consciousness.': 3,
#           'suspected\n': 1,
#           'civilly\n': 1,
#           'astonishing\n': 1,
#           'for?': 1,
#           'purse,': 1,
#           'plans.': 2,
#           'on-': 3,
#           'connexions,': 3,
#           'yards ': 6,
#           'shameful.': 1,
#           'circumstance\n': 3,
#           'planned;': 1,
#           'small\n': 1,
#           'hurchill!': 3,
#           'out\n': 11,
#           'moving,': 2,
#           'thinks\n': 2,
#           'face ': 15,
#           'regretted ': 3,
#           'devoted\n': 1,
#           'blushed ': 3,
#           'contemptuous\n': 1,
#           'olonel\n': 2,
#           'distaste ': 1,
#           'exultation,': 1,
#           'dear,': 60,
#           'longer-': 3,
#           'himself,': 30,
#           'unpleasant,': 2,
#           'pleasure!': 1,
#           'sweetbread ': 2,
#           'foolish.': 1,
#           'natural:': 1,
#           'warmly;': 1,
#           'nobody.': 3,
#           'arrogance ': 3,
#           'astonishment,': 2,
#           'breathing!': 1,
#           'anticipated-': 1,
#           'daughters ': 4,
#           'preserving ': 1,
#           'plans ': 3,
#           'subsequent\n': 1,
#           'forward\n': 3,
#           'sound.': 3,
#           'triumph ': 5,
#           'desperately\n': 1,
#           'touch ': 8,
#           'honoured.': 2,
#           'marriage-': 1,
#           'eymouth,': 6,
#           'week.': 7,
#           'talk-': 2,
#           'virtues ': 1,
#           'long.': 7,
#           'scrape,': 1,
#           'speculation ': 5,
#           'finished ': 5,
#           'are,': 10,
#           'trifle,': 2,
#           'habit-': 1,
#           'lost!': 1,
#           'handed ': 4,
#           'publicity.': 1,
#           'hoped\n': 4,
#           'awakened ': 1,
#           'aunt,': 14,
#           'prospect,': 1,
#           'declare!': 1,
#           'boiled\n': 1,
#           "mma'": 80,
#           'eal,': 1,
#           'would_': 1,
#           'intermediate ': 1,
#           'fathomed ': 1,
#           'excepted.': 1,
#           'blown ': 1,
#           'wine?': 1,
#           'attentively.': 1,
#           'delays\n': 1,
#           'heir,': 1,
#           'projected ': 2,
#           'acted ': 3,
#           'else-': 4,
#           'myself.': 23,
#           'mean ': 37,
#           'image ': 1,
#           'meetings.': 1,
#           'best ': 61,
#           'apple-': 5,
#           'scarcely\n': 3,
#           'hearted-': 1,
#           'liked.': 2,
#           'night!': 2,
#           'though\n': 7,
#           'behind-': 1,
#           'ith ': 30,
#           'should\n': 15,
#           'texts ': 1,
#           'foot ': 3,
#           'taste;': 2,
#           'observing-': 1,
#           'dispiriting ': 1,
#           'zeal\n': 1,
#           'uncertain ': 1,
#           'drink ': 2,
#           'associate,': 1,
#           'deserve\n': 1,
#           'ladies\n': 3,
#           'caps.': 1,
#           'gentle.': 1,
#           'apprehension ': 6,
#           'exploring!': 1,
#           'ltogether ': 1,
#           'sights ': 1,
#           'pen ': 2,
#           'enclosed.': 1,
#           'puppyism.': 1,
#           'gratitude\n': 2,
#           'can.': 13,
#           'shall\n': 11,
#           'persuasively,': 1,
#           'means-': 2,
#           'hindrance ': 1,
#           'rendered ': 6,
#           'deserve.': 6,
#           'intermission ': 1,
#           'upon ': 123,
#           'wit,': 2,
#           'gaiters,': 1,
#           'distress,': 1,
#           'figure,': 3,
#           'pondering,': 1,
#           'alliance,': 2,
#           'powers?': 1,
#           'wife,': 20,
#           'ere,': 4,
#           'manner;': 4,
#           'supposes ': 1,
#           'largest.': 1,
#           'syllables\n': 1,
#           'mallridge,': 2,
#           'compliment ': 17,
#           'walnuts\n': 1,
#           'destroy ': 3,
#           'safest ': 1,
#           'inferior,': 3,
#           'oddard?': 1,
#           'sufferings ': 3,
#           'healed ': 1,
#           'kindred ': 1,
#           'feelingly.': 1,
#           'shock-': 1,
#           'colour ': 3,
#           'ideas ': 8,
#           'larger ': 6,
#           'mutton ': 2,
#           'overcharged ': 2,
#           'communicative\n': 1,
#           'incessant\n': 1,
#           "heroine'": 1,
#           'enry,': 3,
#           'estimation,': 2,
#           'begged\n': 2,
#           'ixty-': 1,
#           'directed ': 5,
#           'invalids ': 1,
#           'rejoiced ': 3,
#           'emember ': 2,
#           'us_': 3,
#           'delighted,': 2,
#           'sleek,': 1,
#           'broke_': 2,
#           'irksome.': 1,
#           'feelings,': 28,
#           'education-': 1,
#           'accent,': 3,
#           'inherited ': 2,
#           'ran.': 1,
#           'sacrifice ': 5,
#           'undoubtedly;': 1,
#           'estate,': 1,
#           'curiosity ': 18,
#           'convinced ': 27,
#           'single ': 14,
#           'vainly;': 1,
#           'dispense ': 2,
#           '`': 112,
#           'begin.': 1,
#           'table;': 1,
#           'argumentative ': 1,
#           'impertinently ': 1,
#           'of\n': 74,
#           'attending ': 6,
#           'considerate,': 1,
#           'morrow\n': 1,
#           'folly ': 8,
#           'seen\n': 9,
#           'irth,': 1,
#           'your\n': 16,
#           'illness;': 1,
#           'resentment ': 3,
#           'side!': 1,
#           'repulsive ': 1,
#           'strangers ': 1,
#           'temper.': 8,
#           'enormous ': 1,
#           'cheerful\n': 2,
#           'attitude,': 2,
#           'sigh ': 4,
#           'saying\n': 4,
#           'ask,': 3,
#           'waltz;': 1,
#           'change;': 4,
#           'does.': 12,
#           'expiation.': 1,
#           'quitted\n': 1,
#           'variations.': 1,
#           "se'": 1,
#           'seventeen,': 2,
#           'observed,': 8,
#           'lucky ': 3,
#           'falls ': 1,
#           'secret.': 2,
#           'exulting,': 1,
#           'her;': 53,
#           'I': 4016,
#           'between ': 68,
#           'affection,': 12,
#           'benefited\n': 1,
#           'hether ': 3,
#           'gentleman-': 4,
#           'yesterday.': 6,
#           'delay ': 11,
#           'order.': 1,
#           'ontrary ': 1,
#           'exceedingly.': 1,
#           'acceptable,': 1,
#           'ox;': 1,
#           'countenance.': 2,
#           'desirable\n': 1,
#           'breakfast ': 3,
#           'worse;': 1,
#           'scruples ': 6,
#           'feeling;': 1,
#           'universal ': 1,
#           'rank ': 182,
#           'voice.': 6,
#           'increased;': 3,
#           'error\n': 1,
#           'remembered\n': 3,
#           'maintained ': 2,
#           'pangs ': 1,
#           'moderately.': 1,
#           'habit ': 8,
#           'damp ': 3,
#           'espionage,': 1,
#           'opened\n': 2,
#           'fairest ': 2,
#           'eye-': 7,
#           'absence ': 7,
#           'only,': 6,
#           'regard,': 3,
#           'missed,': 2,
#           'please.': 7,
#           'ctually ': 2,
#           'impression,': 1,
#           'inclination)': 1,
#           'ork ': 1,
#           'cheering;': 1,
#           'older-': 1,
#           'detestable ': 1,
#           'loud ': 4,
#           'im!': 1,
#           'snow\n': 1,
#           'succeeded ': 7,
#           'amused;': 3,
#           'concurrence.': 1,
#           'rationally.': 1,
#           'shilling ': 1,
#           'inconstancy\n': 1,
#           'already ': 25,
#           'perfectly;': 1,
#           'smiles,': 3,
#           'lime ': 1,
#           'more!': 1,
#           "hour'": 5,
#           'triumphant ': 1,
#           'instrumental,': 1,
#           'ow?': 1,
#           'removed,': 1,
#           'just\n': 7,
#           'mean!': 1,
#           'alliance.': 1,
#           'conveyed ': 7,
#           'if\n': 5,
#           'oodhouse_': 1,
#           'professions ': 4,
#           'library,': 1,
#           'seldom\n': 3,
#           'becomes.': 1,
#           'way\n': 8,
#           'ramer.': 1,
#           'ingston ': 2,
#           'preconceived.': 1,
#           'shortly ': 3,
#           'naturally\n': 2,
#           'beauties.': 1,
#           'pointed,': 2,
#           'grateful\n': 1,
#           'fix ': 8,
#           'unsuitable ': 2,
#           'moderate,': 1,
#           'ates-': 3,
#           'coldness;': 1,
#           'wrapt ': 2,
#           'if ': 366,
#           'advising ': 2,
#           'married\n': 2,
#           'higher,': 1,
#           'conferring ': 1,
#           'graceful ': 3,
#           'befriend ': 1,
#           'nieces!': 1,
#           'bowed.': 1,
#           'hue ': 2,
#           'serviceable ': 2,
#           'officer ': 1,
#           'portfolio ': 1,
#           'impulse ': 1,
#           'collect;': 1,
#           'tremblings ': 1,
#           'iving ': 1,
#           'towards\n': 1,
#           'person\n': 2,
#           'blunders ': 3,
#           'one\n': 16,
#           'its\n': 5,
#           'language.': 1,
#           'following ': 12,
#           'wonderings,': 1,
#           'safe)': 1,
#           'overpowered\n': 1,
#           'morning-': 4,
#           'satisfactory\n': 1,
#           'reasonable ': 13,
#           'ampbell;': 2,
#           'olonel ': 36,
#           'houses ': 4,
#           'agrees ': 2,
#           'often,': 5,
#           'us\n': 4,
#           'cope\n': 1,
#           'looked!': 2,
#           'you ': 1299,
#           'what.': 2,
#           'confused.': 1,
#           'book ': 5,
#           'unworthy\n': 1,
#           'palatable ': 1,
#           'nature.': 3,
#           'fish-': 1,
#           'persuaded;': 1,
#           'row ': 1,
#           'fully ': 14,
#           'dismal ': 1,
#           'hilippics ': 1,
#           'slow ': 4,
#           'useable;': 1,
#           'ordered ': 8,
#           'cogitation ': 1,
#           'ilberts,': 1,
#           'assured\n': 2,
#           'families-': 1,
#           'unfit\n': 1,
#           'practise\n': 1,
#           'men;': 1,
#           'breathing.': 1,
#           'shaking ': 4,
#           'does\n': 7,
#           'sound-': 1,
#           'reserves ': 1,
#           'them\n': 16,
#           'sarcastic ': 1,
#           'verse,': 1,
#           'syllable ': 9,
#           'girl.': 3,
#           'irresistibly ': 1,
#           'buttons ': 1,
#           'vanity-': 3,
#           'completest ': 1,
#           'string,': 1,
#           'ircumstances ': 1,
#           'inadequate ': 2,
#           'attended ': 9,
#           'aylor-': 3,
#           'hatever ': 4,
#           'flight ': 1,
#           'thick-': 1,
#           'broken ': 3,
#           'bestow\n': 1,
#           'entertaining,': 1,
#           'say:': 1,
#           'faults;': 1,
#           'increase ': 10,
#           'headed ': 2,
#           'question.': 9,
#           'M': 2796,
#           'fruitless ': 1,
#           'nd ': 212,
#           'it,': 178,
#           'beg\n': 1,
#           'correctly\n': 1,
#           'discontent.': 1,
#           'artist.': 1,
#           'sweetly.': 1,
#           'interruption;': 1,
#           'tremble!': 1,
#           'undertook ': 1,
#           'future ': 9,
#           'endure ': 11,
#           'blue ': 4,
#           'obliging,': 7,
#           'draper.': 1,
#           'project\n': 1,
#           'infection,': 1,
#           'unexceptionable ': 3,
#           'hough,': 1,
#           'ray ': 10,
#           'impelled\n': 1,
#           'delusion ': 1,
#           'ourselves-': 1,
#           'ungrateful,': 2,
#           'nonsense?': 1,
#           'imagined?': 1,
#           'obligation ': 2,
#           'arriage,': 1,
#           'arose,': 2,
#           'compassion-': 1,
#           'riddle-': 1,
#           'steadiness\n': 1,
#           'will;': 2,
#           'unday ': 1,
#           'heritage.': 1,
#           'aspect;': 1,
#           'ilmans,': 1,
#           'business?': 1,
#           'embarrassment.': 2,
#           'working ': 4,
#           'kingdom\n': 1,
#           'answer!': 2,
#           'first:': 1,
#           'living ': 12,
#           'see\n': 14,
#           'welcome,': 1,
#           'contemplation ': 1,
#           'lead,': 3,
#           'assuring ': 2,
#           'circumstances.': 1,
#           'perceive,': 1,
#           'differently.': 3,
#           'instead ': 20,
#           'mental ': 2,
#           'anywhere;': 2,
#           "gentleman'": 9,
#           'uneasiness ': 5,
#           'figuratively,': 1,
#           'originally ': 1,
#           'use,': 1,
#           'imagine,': 8,
#           'restoration ': 1,
#           'chicken,': 1,
#           "do'": 1,
#           'thoughtful-': 1,
#           'affairs,': 4,
#           'exceeding ': 1,
#           'footstep\n': 1,
#           'brilliant!': 2,
#           'in,': 22,
#           'entirely;': 1,
#           'fetch\n': 1,
#           'competent ': 2,
#           'atroness,': 1,
#           'neither.': 2,
#           'again ': 64,
#           'hungry,': 2,
#           'marks ': 2,
#           'ordered.': 1,
#           'mentioned;': 2,
#           'entered\n': 3,
#           'naturally;': 1,
#           'obliging!': 3,
#           'peculiarities ': 1,
#           'must.': 3,
#           'witty ': 2,
#           'observing ': 4,
#           'called,': 2,
#           'oftener ': 4,
#           'urry.': 1,
#           'ungracious ': 1,
#           '_': 390,
#           'sure;': 4,
#           'thing,': 26,
#           'divert ': 1,
#           'hink ': 2,
#           'dearer\n': 1,
#           'shine ': 1,
#           'separated ': 2,
#           'enjoy ': 8,
#           'caresses;': 1,
#           'preparing\n': 1,
#           'lip,': 2,
#           'ungallant,': 1,
#           'throat;': 2,
#           'heat-': 1,
#           'deviation ': 1,
#           'disapprobation;': 1,
#           'lawn;': 1,
#           'tell.': 6,
#           'like!': 1,
#           'cure.': 2,
#           'contrast ': 5,
#           'account-': 2,
#           'es.': 6,
#           'fall\n': 1,
#           'associates ': 1,
#           'artin-': 1,
#           'sorrowful\n': 1,
#           'increase\n': 1,
#           'direct\n': 4,
#           'understanding-': 1,
#           'with\n': 33,
#           'evils,': 2,
#           'hesitation\n': 1,
#           'intimate,': 1,
#           'this\n': 9,
#           'submission ': 2,
#           'confused-': 1,
#           'strengthened ': 4,
#           'teased ': 1,
#           'it:': 4,
#           'final ': 1,
#           'complaints ': 1,
#           'crowd;': 1,
#           'piece ': 12,
#           'wait ': 18,
#           'joint ': 3,
#           'loss-': 1,
#           'secondary ': 2,
#           'merited!': 1,
#           'pick ': 1,
#           'boys,': 5,
#           'hems ': 1,
#           'unpardonable ': 3,
#           'encouragement\n': 1,
#           'playfulness\n': 1,
#           'deepest ': 2,
#           'bring ': 33,
#           'benefited,': 1,
#           'also\n': 1,
#           'before!': 1,
#           'ateses-': 1,
#           'proceed.': 2,
#           'render ': 1,
#           'N': 302,
#           'unsuspicious ': 3,
#           'sister,': 7,
#           'soon;': 2,
#           'cheek,': 1,
#           'arkins.': 2,
#           'guests\n': 1,
#           'glad.': 1,
#           'entreated.': 1,
#           'hours,': 3,
#           'space\n': 1,
#           'ridiculous,': 2,
#           'procrastinating ': 1,
#           'rapidity ': 2,
#           'public.': 1,
#           'poplin.': 1,
#           'landau ': 2,
#           'opinion,': 17,
#           'sort;': 5,
#           'subject,': 23,
#           'evasions ': 1,
#           'pays ': 4,
#           'judgment,': 8,
#           'bustle ': 8,
#           'find-': 1,
#           'deal,': 3,
#           'lasting.': 2,
#           'wishes\n': 2,
#           'warmth,': 2,
#           'rencontre,': 2,
#           'excellent,': 1,
#           'portion.': 1,
#           'rooms,': 4,
#           'time-': 10,
#           'subject!': 1,
#           'enough;': 7,
#           'months;': 2,
#           'trembled ': 1,
#           'convenient,': 1,
#           'journey;': 3,
#           'disagree ': 2,
#           'struck ': 21,
#           'step\n': 1,
#           'our ': 115,
#           'proud ': 4,
#           'mind?': 1,
#           'upon,': 1,
#           'signified ': 2,
#           'discover\n': 1,
#           'circumstances\n': 2,
#           'confesses ': 2,
#           'natural.': 3,
#           'passes ': 1,
#           'rejoined ': 1,
#           'notice ': 16,
#           'ridden ': 1,
#           'prevail,': 1,
#           'unreserve\n': 1,
#           'reads ': 2,
#           'screwed ': 1,
#           'pace.': 1,
#           'genteel.': 1,
#           'grown ': 6,
#           'oarding-': 1,
#           'possesses ': 1,
#           'warmer,': 1,
#           'set ': 51,
#           'legant,': 1,
#           'smooth.': 2,
#           'write\n': 4,
#           'enviable ': 1,
#           'ten-': 1,
#           'reflections.': 1,
#           'quick ': 15,
#           'heartily ': 5,
#           'ane-': 3,
#           'dear ': 129,
#           'same,': 1,
#           'difficulty.': 5,
#           'drawn?': 1,
#           'name,': 11,
#           'rights ': 2,
#           'refused.': 2,
#           'thriving ': 1,
#           'transcribing ': 1,
#           'guinea ': 1,
#           'misinterpreted ': 2,
#           'difficult ': 4,
#           'leave-': 2,
#           'table-': 1,
#           'this?': 7,
#           'orse ': 2,
#           'leisure-': 1,
#           'heap ': 1,
#           'awoke,': 1,
#           'uncle ': 13,
#           'make;': 1,
#           'probabilities,': 1,
#           'then"': 2,
#           'cordiality.': 1,
#           'onsider,': 1,
#           'much ': 395,
#           'school;': 1,
#           'hinting ': 1,
#           'cleverer ': 2,
#           'risks.': 2,
#           'rapidly\n': 2,
#           'objections;': 1,
#           'wavering,': 2,
#           'headache\n': 1,
#           'proper\n': 1,
#           'parentage ': 2,
#           'seriousness ': 2,
#           'through ': 48,
#           'comfortable.': 2,
#           'calculate ': 1,
#           'spent;': 1,
#           'perverse ': 1,
#           'urgency,': 1,
#           'considerable.': 3,
#           'threadbare,': 1,
#           'adequate ': 1,
#           'indubitable ': 2,
#           'improper\n': 1,
#           'laughing.': 2,
#           'self-': 19,
#           'plain.': 4,
#           'secured.': 2,
#           'seat,': 1,
#           'gather ': 2,
#           'good;': 5,
#           'air.': 8,
#           'leniently ': 1,
#           'wrong,': 13,
#           'care ': 41,
#           'happily,': 1,
#           'relish ': 1,
#           'steep ': 1,
#           'herself\n': 15,
#           'direction ': 2,
#           'forming,': 1,
#           'owever,': 17,
#           'gold ': 1,
#           'vigorously,': 2,
#           'fearless ': 1,
#           'dies,': 1,
#           'rd ': 1,
#           'letters;': 1,
#           'health.': 5,
#           'dread\n': 1,
#           'behaved,': 1,
#           'assailed ': 1,
#           'inimitable ': 2,
#           'precaution.': 1,
#           'suspected ': 9,
#           'servant ': 3,
#           'principles.': 1,
#           'connecting ': 1,
#           'featured ': 1,
#           'reflection,': 5,
#           'nephew ': 8,
#           'quicker,': 1,
#           'neat,': 2,
#           'confusion,': 1,
#           'bbey!': 1,
#           'weather ': 22,
#           'decease.': 1,
#           'fancies ': 1,
#           'resigned.': 2,
#           'sober:': 1,
#           'exclaim,': 3,
#           'delight!': 1,
#           'oft ': 1,
#           'brings,': 1,
#           'merest ': 1,
#           'acceded\n': 1,
#           'parsnip,': 1,
#           'worse,': 2,
#           'conquest ': 1,
#           'comprehension.': 2,
#           'y_': 2,
#           'cautious:': 1,
#           'pork ': 1,
#           'testifying ': 1,
#           'wanting\n': 4,
#           'sorry:': 1,
#           'caution;': 3,
#           'chapters,': 1,
#           'raved ': 1,
#           'extremely;': 1,
#           'pursuits ': 1,
#           'deprecated ': 1,
#           'tranquillity ': 3,
#           'lingering\n': 1,
#           'feet?': 1,
#           'dispositions,': 1,
#           'reasonable\n': 1,
#           'coming?': 1,
#           'draws\n': 1,
#           'touchstone,': 1,
#           'suspense.': 2,
#           'fullest ': 2,
#           'shewed,': 1,
#           'wickedness ': 1,
#           'objection,': 3,
#           'where,': 6,
#           'ash,': 3,
#           'mad,': 2,
#           'soon,': 14,
#           'dreaded ': 2,
#           'oppress ': 1,
#           'bottom\n': 1,
#           'briskly ': 2,
#           'fool ': 2,
#           'supper-': 2,
#           'single-': 1,
#           'hristian ': 2,
#           'mediocre_': 1,
#           'commissions,': 1,
#           'uppermost.': 1,
#           'his\n': 40,
#           "aunt'": 5,
#           'scepticism.': 1,
#           'industriously ': 1,
#           'company;': 1,
#           'say.': 8,
#           'deciding\n': 1,
#           'thoughtlessness;': 1,
#           'fine ': 35,
#           'furniture,': 2,
#           'about\n': 10,
#           'fixed ': 16,
#           'sat-': 1,
#           'betweens,': 1,
#           'internal ': 1,
#           'over ': 82,
#           'feelingly;': 1,
#           'change,': 7,
#           'enceforward ': 1,
#           'nobody ': 43,
#           'names,': 1,
#           'health-': 3,
#           'circumstance.': 1,
#           'object-': 3,
#           'usten ': 1,
#           'early!': 1,
#           'his_': 4,
#           'danced-': 1,
#           'poet ': 1,
#           'boils ': 1,
#           'pianoforte ': 6,
#           'mark ': 3,
#           'hearted,': 3,
#           'almost ': 80,
#           'sure ': 150,
#           'love-': 4,
#           'particular_': 1,
#           'strict\n': 1,
#           'stare ': 1,
#           'series\n': 1,
#           'gratification ': 1,
#           'explained ': 1,
#           'going?': 2,
#           'reminding ': 2,
#           'dearer ': 1,
#           'gentleman,': 1,
#           'absence.': 2,
#           'up.': 15,
#           'differently ': 5,
#           'attained ': 1,
#           'invalid-': 1,
#           'will_': 3,
#           'gruel,': 2,
#           'could.': 8,
#           'permanent ': 1,
#           'inelegance ': 1,
#           'send\n': 2,
#           'predicament ': 1,
#           'precisely ': 6,
#           'field ': 2,
#           'immaterial.': 1,
#           'achievement,': 1,
#           'velocity ': 1,
#           'ood ': 16,
#           'front ': 5,
#           'four\n': 5,
#           'interposition-': 1,
#           'creating ': 4,
#           'than,': 3,
#           'alike;': 1,
#           'ead ': 2,
#           'very!': 1,
#           'poison,': 1,
#           'pew,': 2,
#           'stipulation ': 1,
#           'half.': 2,
#           'occurrence:': 1,
#           'passage ': 3,
#           ...})

# %% [markdown]
#  Plot frequency distribution

# %%
data.plot(50) # Plot sorted frequency of top 10 tokens

# %% [markdown]
# # 2-2.Stop words with NLTK

# %% [markdown]
# The process of converting data to something a computer can understand.
#
# In natural language processing, useless words (data), are referred to as stop words.

# %%
from nltk.corpus import stopwords # remove words that just contain no meaning

stop_words=set(stopwords.words('english'))

print(stop_words)
# Out:
# {'under', 'very', 'against', 'once', 'y', 'now', 'her', 'same', 'about', 'o', 'only', 'these', 'few', 'any', 'the', 'up', 'than', 'too', 'll', 'but', 'had', 'from', 'both', 'what', 'down', 'didn', 'on', 'mightn', 'at', 'some', 'until', 'this', 'out', 'own', 'yourself', 'himself', 'further', 'if', 'after', 'should', 'was', 'hadn', 'shouldn', 'is', 'will', 'doesn', 'theirs', 'above', 'me', 'she', 'ma', 'him', 'hasn', 'do', 'which', 'through', 'couldn', 'did', 'so', 's', 'isn', 'herself', 'have', 'then', 'because', 'during', 'he', 'why', 'yourselves', 'were', 'shan', 'hers', 'myself', 'aren', 'be', 'or', 'my', 'whom', 'won', 'other', 'there', 'i', 'its', 'into', 'itself', 'your', 'can', 'doing', 'off', 'to', 'before', 'they', 've', 'between', 'and', 'weren', 'it', 'we', 'am', 'over', 'with', 'each', 'has', 'for', 'again', 'you', 'not', 'ain', 'd', 'ours', 'them', 'no', 'most', 'nor', 'ourselves', 'yours', 'just', 'haven', 'wasn', 'by', 'needn', 'been', 'who', 'more', 'are', 'being', 'such', 'here', 'wouldn', 'don', 'where', 'does', 'that', 'a', 'those', 'below', 'how', 'all', 'an', 'mustn', 'themselves', 'while', 'of', 'as', 'in', 'm', 're', 't', 'our', 'their', 'his', 'when', 'having'}

# %% [markdown]
# # 연습 #1: 주어진 텍스트에서 stop word을 제거하기

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

sentence = "This is a sample sentence, showing off the stop words filtration."

stop_words = set(stopwords.words('english'))
stop_words.add(".")
stop_words.add(",")

tokens = word_tokenize(sentence)

filtered_sentence = [w for w in tokens if not w in stop_words]


print(tokens)
print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ['This', 'sample', 'sentence', 'showing', 'stop', 'words', 'filtration']

# %% [markdown]
# # 2.3.Stemming words with NLTK

# %% [markdown]
# Stemming is a sort of normalizing method.
#
# Many variations of words carry the same meaning, other than when tense is involved :
#
# Highly redundant and inefficient, especially since, once we convert to numbers, the "value" is going to be identical.

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %% [markdown]
# # 연습 #2 :다음 문장을 stemming하여 그 결과를 출력하기(10분)

# %% [markdown]
# new_text = """It is important to by very pythonly while
# you are pythoning with python. All pythoners """

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
new_text = """It is important to by very pythonly
while you are pythoning with python. All pythoners """
words = word_tokenize(new_text)
ps = PorterStemmer()
stemmed=[ps.stem(w) for w in words]
print(stemmed)
# Out:
# ['It', 'is', 'import', 'to', 'by', 'veri', 'pythonli', 'while', 'you', 'are', 'python', 'with', 'python', '.', 'All', 'python']

# %% [markdown]
# # 2.4.Part of Speech Tagging and Chunking with NLTK

# %% [markdown]
# POS tagging means labeling words in a sentence as nouns, adjectives, verbs...etc.

# %% [markdown]
# Chunking means grouping words into hopefully meaningful chunks.
#
# One of the main goals of chunking is to group into what are known as "noun phrases."
#
# The idea is to group nouns with the words that are in relation to them.

# %%
words = nltk.word_tokenize("The little yellow dog barked at the Persian cat")
tagged = nltk.pos_tag(words)
tagged
# Out:
# [('The', 'DT'),
#  ('little', 'JJ'),
#  ('yellow', 'JJ'),
#  ('dog', 'NN'),
#  ('barked', 'VBD'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Persian', 'JJ'),
#  ('cat', 'NN')]

# %%
chunkGram = r"""NP: {<DT>? <JJ>? <NN.*>* }"""
chunkParser = nltk.RegexpParser(chunkGram)

chunked = chunkParser.parse(tagged)

print(chunked)


chunked.draw()
# Out:
# (S
#   (NP The/DT little/JJ)
#   (NP yellow/JJ dog/NN)
#   barked/VBD
#   at/IN
#   (NP the/DT Persian/JJ cat/NN))

# %% [markdown]
# # 연습 #3 :다음 코퍼스을 Tagging & Chunking하여 정보 추출하기(10분)

# %% [markdown]
# Extract special characters using NLTK RegexpParser Chunk for POS_tagged words

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize(sample_text)

print(tokenized[1])

words = nltk.word_tokenize(tokenized[1]) #tokenizing

tagged = nltk.pos_tag(words) #tagging


chunkGram = r"""NP: {<DT>? <JJ>? <NN.*>* }""" #regular expression 
                                  
chunkParser = nltk.RegexpParser(chunkGram)
chunked = chunkParser.parse(tagged) #chunking with nouns
            
print(chunked)

chunked.draw()
# Out:
# Mr. Speaker, Vice President Cheney, members of Congress, members of the Supreme Court and diplomatic corps, distinguished guests, and fellow citizens: Today our nation lost a beloved, graceful, courageous woman who called America to its founding ideals and carried on a noble dream.
# (S
#   (NP Mr./NNP Speaker/NNP)
#   ,/,
#   (NP Vice/NNP President/NNP Cheney/NNP)
#   ,/,
#   (NP members/NNS)
#   of/IN
#   (NP Congress/NNP)
#   ,/,
#   (NP members/NNS)
#   of/IN
#   (NP the/DT Supreme/NNP Court/NNP)
#   and/CC
#   (NP diplomatic/JJ corps/NN)
#   ,/,
#   (NP distinguished/JJ guests/NNS)
#   ,/,
#   and/CC
#   (NP fellow/JJ citizens/NNS)
#   :/:
#   Today/VB
#   our/PRP$
#   (NP nation/NN)
#   lost/VBD
#   (NP a/DT)
#   beloved/VBN
#   ,/,
#   (NP graceful/JJ)
#   ,/,
#   (NP courageous/JJ woman/NN)
#   who/WP
#   called/VBD
#   (NP America/NNP)
#   to/TO
#   its/PRP$
#   (NP founding/NN ideals/NNS)
#   and/CC
#   carried/VBD
#   on/IN
#   (NP a/DT noble/JJ dream/NN)
#   ./.)

# %%
data=nltk.Text(words)  

print(len(data.tokens))  # returns number of tokens (document length)

print(len(set(tokens))) # returns number of unique tokens

data.vocab() # returns frequency distribution

data.plot(15)  # Plot sorted frequency of top 50 tokens

data.count('PRESIDENT')  # Counts occurrences

data.concordance('a', lines=2)

data.collocations()
# Out:
# 52
# 13
# Displaying 2 of 2 matches:
# ellow citizens : Today our nation lost a beloved , graceful , courageous woman
#  to its founding ideals and carried on a noble dream .

# %% [markdown]
# # 2.5. Named Entity Recognition with NLTK

# %% [markdown]
# One of the most major forms of chunking in natural language processing is called "Named Entity Recognition." The idea is to have the machine immediately be able to pull out "entities" like people, places, things, locations, monetary figures, and more.

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize(sample_text)

words = nltk.word_tokenize(tokenized[0])
tagged = nltk.pos_tag(words)
namedEnt = nltk.ne_chunk(tagged, binary=False)
namedEnt.draw()

# %% [markdown]
# # 2.6. Lemmatizing with NLTK

# %% [markdown]
# A very similar operation to stemming
#
# Stemming can often create non-existent words, whereas lemmas are actual words.
#
# Root stem, meaning the word you end up with, is not something you can just look up in a dictionary, but look up a lemma.
#
# Parameter, "pos." If not supplied, the default is "noun."

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize("cats"))
print(lemmatizer.lemmatize("cacti"))
print(lemmatizer.lemmatize("geese"))
print(lemmatizer.lemmatize("rocks"))
print(lemmatizer.lemmatize("python"))
print(lemmatizer.lemmatize("better", pos="a"))
print(lemmatizer.lemmatize("best", pos="a"))
print(lemmatizer.lemmatize("run"))
print(lemmatizer.lemmatize("run",'v'))
# Out:
# cat
# cactus
# goose
# rock
# python
# good
# best
# run
# run

# %% [markdown]
# # #Wordnet with NLTK

# %% [markdown]
# Wordnet is a collection of words, definitions, examples of their use, synonyms, antonyms, and more.
#
# https://wordnet.princeton.edu/wordnet/
#
# WordNet is a lexical database for the English language, which was created by Princeton, and is part of the NLTK corpus.
#
# You can use WordNet alongside the NLTK module to find the meanings of words, synonyms, antonyms, and more.

# %%
from nltk.corpus import wordnet

# %%
syns=wordnet.synsets("program") #An example of a synset:
print(syns)
print(syns[0].name()) 

print(syns[0].lemmas()[0].name()) #just the word

print(syns[0].definition()) # definition of the first synset
# Out:
# [Synset('plan.n.01'), Synset('program.n.02'), Synset('broadcast.n.02'), Synset('platform.n.02'), Synset('program.n.05'), Synset('course_of_study.n.01'), Synset('program.n.07'), Synset('program.n.08'), Synset('program.v.01'), Synset('program.v.02')]
# plan.n.01
# plan
# a series of steps to be carried out or goals to be accomplished

# %% [markdown]
# Next, how might we discern synonyms and antonyms to a word? The lemmas will be synonyms, and then you can use .antonyms to find the antonyms to the lemmas.

# %% [markdown]
# 문법:
#
# list=[]
#
# for x in range(10):
#     list.append(x)
#
# print(set(list))

# %%
synonyms = []
antonyms = []

for syn in wordnet.synsets("good"):
    for x in syn.lemmas():
        synonyms.append(x.name())
        if x.antonyms():
            antonyms.append(x.antonyms()[0].name())

print(set(synonyms))
print(set(antonyms))
# Out:
# {'expert', 'beneficial', 'in_effect', 'near', 'thoroughly', 'salutary', 'sound', 'adept', 'dependable', 'right', 'in_force', 'safe', 'full', 'estimable', 'skillful', 'dear', 'skilful', 'undecomposed', 'proficient', 'honorable', 'unspoiled', 'effective', 'soundly', 'unspoilt', 'trade_good', 'ripe', 'secure', 'commodity', 'honest', 'upright', 'goodness', 'practiced', 'respectable', 'just', 'serious', 'well', 'good'}
# {'evilness', 'bad', 'evil', 'badness', 'ill'}

# %% [markdown]
# use WordNet to compare the similarity of two words and their tenses, by incorporating the Wu and Palmer method for semantic related-ness.
#
#  compare the noun of "ship" and "boat:"

# %%
w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('boat.n.01')
print(w1.wup_similarity(w2))
# Out:
# 0.9090909090909091

# %% [markdown]
# # # Text Classification with NLTK : Movie reviewer

# %% [markdown]
# The goal with text classification can be pretty broad.
#
# Maybe we're trying to classify text as about politics or the military.
#
# Maybe we're trying to classify it by the gender of the author who wrote it.
#
# A fairly popular text classification task is to identify a body of text as either spam or not spam, for things like email filters.
#
# we're going to try to create a sentiment analysis algorithm with customer reviewers

# %% [markdown]
# To do this,
#
# 1. start by trying to use the movie reviews database that is part of the NLTK corpus.
#
# 2. use words as "features" which are a part of either a positive or negative movie review.
#
# 3. the NLTK corpus movie_reviews data set has the reviews, and they are labeled already as positive or negative.
#
# 4. train and test with this data.

# %%
import nltk
import random
from nltk.corpus import movie_reviews

documents = [[movie_reviews.words(fileid), category]
             for category in movie_reviews.categories()
             #if category=='pos'
             for fileid in movie_reviews.fileids(category)]


random.shuffle(documents)

print(documents[1])

all_words = []

for w in movie_reviews.words():
    all_words.append(w.lower())

all_words = nltk.FreqDist(all_words)

print(all_words.most_common(15))
print(all_words["terrible"])
# Out:
# [['i', 'had', 'been', 'looking', 'forward', 'to', ...], 'neg']
# [(',', 77717), ('the', 76529), ('.', 65876), ('a', 38106), ('and', 35576), ('of', 34123), ('to', 31937), ("'", 30585), ('is', 25195), ('in', 21822), ('s', 18513), ('"', 17612), ('it', 16107), ('that', 15924), ('-', 15595)]
# 143

# %% [markdown]
# # 1.Converting words to Features with NLTK

# %%
print(all_words)

word_features=[w for w in all_words][:3000] #set word_features, which contains the top 3,000 most common words.
 
#print(word_features)
# Out:
# <FreqDist with 39768 samples and 1583820 outcomes>

# %%
def find_features(document):   # find these top 3,000 words in our positive and negative documents, 
                               #marking their presence as either positive or negative:
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

#print((find_features(movie_reviews.words('neg/cv000_29416.txt'))))

# %%
# do this for all of our documents, 
# saving the feature existence booleans 
#  and their respective positive or negative categories 
featuresets = [(find_features(rev), category) for (rev, category) in documents]

# %% [markdown]
# # 2. Supervised Machine learning

# %% [markdown]
# 1.Chose an algorithm : the Naive Bayes classifier. This is a pretty popular algorithm used in text classification, so it is only fitting that we try it out first.
#
# 2.Separate our data into training and testing sets
#
# 3. To do this :
#
# Shuffle our data se
#
# Assign the first 1,900 shuffled reviews, consisting of both positive and negative reviews, as the training set.
#
# Then, test against the last 100 to see how accurate we are.
#
# This is called supervised machine learning, because we're showing the machine data, and telling it "hey, this data is positive," or "this data is negative." Then, after that training is done, we show the machine some new data and ask the computer, based on what we taught the computer before, what the computer thinks the category of the new data is.

# %%
training_set = featuresets[:1900] # set that we'll train our classifier with

testing_set = featuresets[1900:] # set that we'll test against.

# %%
classifier = nltk.NaiveBayesClassifier.train(training_set) # train our classifier like:

# %%
classifier.show_most_informative_features(20) #see what the most valuable words are when it comes to positive or negative reviews:
# Out:
# Most Informative Features
#               astounding = True              pos : neg    =     12.3 : 1.0
#              outstanding = True              pos : neg    =     10.9 : 1.0
#                stupidity = True              neg : pos    =      9.1 : 1.0
#                   feeble = True              neg : pos    =      8.4 : 1.0
#                  frances = True              pos : neg    =      8.3 : 1.0
#                behaviour = True              pos : neg    =      7.6 : 1.0
#                   crappy = True              neg : pos    =      7.0 : 1.0
#                  supreme = True              pos : neg    =      7.0 : 1.0
#                     moss = True              pos : neg    =      6.3 : 1.0
#                  notions = True              pos : neg    =      5.6 : 1.0
#                   justin = True              neg : pos    =      5.4 : 1.0
#                  lambert = True              neg : pos    =      5.0 : 1.0
#                   farley = True              neg : pos    =      5.0 : 1.0
#                 billions = True              neg : pos    =      5.0 : 1.0
#                     1982 = True              neg : pos    =      5.0 : 1.0
#                     oops = True              neg : pos    =      5.0 : 1.0
#             effortlessly = True              pos : neg    =      5.0 : 1.0
#                    guilt = True              pos : neg    =      5.0 : 1.0
#                   equals = True              pos : neg    =      5.0 : 1.0
#                   winter = True              pos : neg    =      5.0 : 1.0

# %% [markdown]
# # Saving Classifiers with NLTK

# %% [markdown]
#  no longer need to train our classifier every time we wanted to use it to classify.

# %%
import pickle
save_classifier = open("naivebayes.pickle","wb")
pickle.dump(classifier, save_classifier)
save_classifier.close()

classifier_f = open("naivebayes.pickle", "rb")
classifier = pickle.load(classifier_f)
classifier_f.close()

# %% [markdown]
# #  Toy Data for sentiment analysis with NLTK

# %% [markdown]
# https://pythonprogramming.net/static/downloads/short_reviews/

# %%
import nltk
from nltk.tokenize import word_tokenize
import random
short_pos = open("positive.txt","r").read()
short_neg = open("negative.txt","r").read()

documents = []

for r in short_pos.split('\n'):
    documents.append( (r, "pos") )

for r in short_neg.split('\n'):
    documents.append( (r, "neg") )


all_words = []

short_pos_words = word_tokenize(short_pos)
short_neg_words = word_tokenize(short_neg)

for w in short_pos_words:
    all_words.append(w.lower())

for w in short_neg_words:
    all_words.append(w.lower())

all_words = nltk.FreqDist(all_words)

# %% [markdown]
# convert words to features

# %%
word_features=[w for w in all_words][:5000]

def find_features(document):
    words = word_tokenize(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

featuresets = [(find_features(rev), category) for (rev, category) in documents]

random.shuffle(featuresets)

# %%
# positive data example:      
training_set = featuresets[:10000]
testing_set =  featuresets[10000:]

# %% [markdown]
# # #A module for Sentiment Analysis with NLTK

# %%
import nltk
import random
#from nltk.corpus import movie_reviews
from nltk.classify.scikitlearn import SklearnClassifier
import pickle
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from nltk.classify import ClassifierI
from statistics import mode
from nltk.tokenize import word_tokenize



class VoteClassifier(ClassifierI):
    def __init__(self, *classifiers):
        self._classifiers = classifiers

    def classify(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
        return mode(votes)

    def confidence(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)

        choice_votes = votes.count(mode(votes))
        conf = choice_votes / len(votes)
        return conf
    
short_pos = open("positive.txt","r").read()
short_neg = open("negative.txt","r").read()

# move this up here
all_words = []
documents = []


#  j is adject, r is adverb, and v is verb
#allowed_word_types = ["J","R","V"]
allowed_word_types = ["J"]

for p in short_pos.split('\n'):
    documents.append( (p, "pos") )
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    for w in pos:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())

    
for p in short_neg.split('\n'):
    documents.append( (p, "neg") )
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    for w in pos:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())



save_documents = open("documents.pickle","wb")
pickle.dump(documents, save_documents)
save_documents.close()


all_words = nltk.FreqDist(all_words)


word_features = list(all_words.keys())[:5000]


save_word_features = open("word_features5k.pickle","wb")
pickle.dump(word_features, save_word_features)
save_word_features.close()


def find_features(document):
    words = word_tokenize(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

featuresets = [(find_features(rev), category) for (rev, category) in documents]

save_featuresets = open("featuresets.pickle","wb")
pickle.dump(featuresets, save_featuresets)
save_featuresets.close()

random.shuffle(featuresets)
print(len(featuresets))

testing_set = featuresets[10000:]
training_set = featuresets[:10000]


classifier = nltk.NaiveBayesClassifier.train(training_set)
print("Original Naive Bayes Algo accuracy percent:", (nltk.classify.accuracy(classifier, testing_set))*100)
classifier.show_most_informative_features(15)

###############
save_classifier = open("originalnaivebayes5k.pickle","wb")
pickle.dump(classifier, save_classifier)
save_classifier.close()

MNB_classifier = SklearnClassifier(MultinomialNB())
MNB_classifier.train(training_set)
print("MNB_classifier accuracy percent:", (nltk.classify.accuracy(MNB_classifier, testing_set))*100)

save_classifier = open("MNB_classifier5k.pickle","wb")
pickle.dump(MNB_classifier, save_classifier)
save_classifier.close()

BernoulliNB_classifier = SklearnClassifier(BernoulliNB())
BernoulliNB_classifier.train(training_set)
print("BernoulliNB_classifier accuracy percent:", (nltk.classify.accuracy(BernoulliNB_classifier, testing_set))*100)

save_classifier = open("BernoulliNB_classifier5k.pickle","wb")
pickle.dump(BernoulliNB_classifier, save_classifier)
save_classifier.close()

LogisticRegression_classifier = SklearnClassifier(LogisticRegression())
LogisticRegression_classifier.train(training_set)
print("LogisticRegression_classifier accuracy percent:", (nltk.classify.accuracy(LogisticRegression_classifier, testing_set))*100)

save_classifier = open("LogisticRegression_classifier5k.pickle","wb")
pickle.dump(LogisticRegression_classifier, save_classifier)
save_classifier.close()


LinearSVC_classifier = SklearnClassifier(LinearSVC())
LinearSVC_classifier.train(training_set)
print("LinearSVC_classifier accuracy percent:", (nltk.classify.accuracy(LinearSVC_classifier, testing_set))*100)

save_classifier = open("LinearSVC_classifier5k.pickle","wb")
pickle.dump(LinearSVC_classifier, save_classifier)
save_classifier.close()


##NuSVC_classifier = SklearnClassifier(NuSVC())
##NuSVC_classifier.train(training_set)
##print("NuSVC_classifier accuracy percent:", (nltk.classify.accuracy(NuSVC_classifier, testing_set))*100)


SGDC_classifier = SklearnClassifier(SGDClassifier())
SGDC_classifier.train(training_set)
print("SGDClassifier accuracy percent:",nltk.classify.accuracy(SGDC_classifier, testing_set)*100)

save_classifier = open("SGDC_classifier5k.pickle","wb")
pickle.dump(SGDC_classifier, save_classifier)
save_classifier.close()
# Out:
# 10663
# Original Naive Bayes Algo accuracy percent: 73.7556561085973
# Most Informative Features
#               engrossing = True              pos : neg    =     21.0 : 1.0
#                wonderful = True              pos : neg    =     20.3 : 1.0
#                  routine = True              neg : pos    =     16.4 : 1.0
#                  generic = True              neg : pos    =     15.7 : 1.0
#                inventive = True              pos : neg    =     15.0 : 1.0
#                   boring = True              neg : pos    =     13.0 : 1.0
#                     warm = True              pos : neg    =     13.0 : 1.0
#                 intimate = True              pos : neg    =     13.0 : 1.0
#                 mindless = True              neg : pos    =     11.7 : 1.0
#                    stale = True              neg : pos    =     11.7 : 1.0
#               refreshing = True              pos : neg    =     11.6 : 1.0
#                   stupid = True              neg : pos    =     11.0 : 1.0
#                 touching = True              pos : neg    =     10.7 : 1.0
#                 annoying = True              neg : pos    =     10.3 : 1.0
#                 tiresome = True              neg : pos    =     10.3 : 1.0
# MNB_classifier accuracy percent: 72.39819004524887
# BernoulliNB_classifier accuracy percent: 73.7556561085973
# LogisticRegression_classifier accuracy percent: 72.54901960784314
# LinearSVC_classifier accuracy percent: 69.68325791855203
# SGDClassifier accuracy percent: 69.98491704374057

# %%
# %%writefile sentiment_mod.py
#File: sentiment_mod.py

import nltk
import random
#from nltk.corpus import movie_reviews
from nltk.classify.scikitlearn import SklearnClassifier
import pickle
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from nltk.classify import ClassifierI
from statistics import mode
from nltk.tokenize import word_tokenize



class VoteClassifier(ClassifierI):
    def __init__(self, *classifiers):
        self._classifiers = classifiers

    def classify(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
        return mode(votes)

    def confidence(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)

        choice_votes = votes.count(mode(votes))
        conf = choice_votes / len(votes)
        return conf


documents_f = open("documents.pickle", "rb")
documents = pickle.load(documents_f)
documents_f.close()




word_features5k_f = open("word_features5k.pickle", "rb")
word_features = pickle.load(word_features5k_f)
word_features5k_f.close()


def find_features(document):
    words = word_tokenize(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features



featuresets_f = open("featuresets.pickle", "rb")
featuresets = pickle.load(featuresets_f)
featuresets_f.close()

random.shuffle(featuresets)
print(len(featuresets))

testing_set = featuresets[10000:]
training_set = featuresets[:10000]



open_file = open("originalnaivebayes5k.pickle", "rb")
classifier = pickle.load(open_file)
open_file.close()


open_file = open("MNB_classifier5k.pickle", "rb")
MNB_classifier = pickle.load(open_file)
open_file.close()



open_file = open("BernoulliNB_classifier5k.pickle", "rb")
BernoulliNB_classifier = pickle.load(open_file)
open_file.close()


open_file = open("LogisticRegression_classifier5k.pickle", "rb")
LogisticRegression_classifier = pickle.load(open_file)
open_file.close()


open_file = open("LinearSVC_classifier5k.pickle", "rb")
LinearSVC_classifier = pickle.load(open_file)
open_file.close()


open_file = open("SGDC_classifier5k.pickle", "rb")
SGDC_classifier = pickle.load(open_file)
open_file.close()




voted_classifier = VoteClassifier(
                                  classifier,
                                  LinearSVC_classifier,
                                  MNB_classifier,
                                  BernoulliNB_classifier,
                                  LogisticRegression_classifier)




def sentiment(text):
    feats = find_features(text)
    return voted_classifier.classify(feats),voted_classifier.confidence(feats)
# Out:
# Overwriting sentiment_mod.py
